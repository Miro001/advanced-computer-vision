# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import torchvision
from torch.utils.data import DataLoader
from IPython.display import clear_output
from early_stopping.pytorchtools import EarlyStopping

# %matplotlib inline
torch.manual_seed(17)
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
plt.rcParams['text.color'] = 'w'
plt.rcParams['xtick.color'] = 'w'
plt.rcParams['ytick.color'] = 'w'
plt.rcParams['axes.labelcolor'] = 'w'
font = {'family' : 'DejaVu Sans',
        'weight' : 'normal',
        'size'   : 14}
plt.rc('font', **font)

# %%
min_transform = torchvision.transforms.Compose([
                                    torchvision.transforms.ToTensor(),
                                    #torchvision.transforms.RandomErasing()
                                    ])
data_transform = torchvision.transforms.Compose([
                                    torchvision.transforms.ToTensor(),
                                    #torchvision.transforms.RandomErasing(),
                                    #torchvision.transforms.RandomVerticalFlip(),
                                    #torchvision.transforms.RandomHorizontalFlip(),
                                    #torchvision.transforms.RandomAffine(180,
                                    #                                    translate=(0.1, 0.1),
                                    #                                    scale=(0.75,1.25))
                                    ])

dataset = torchvision.datasets.CIFAR10("/media/miro/4tb_cached/",
                                       transform=data_transform,
                                       download=True)

fig, axs = plt.subplots(4, 4,figsize=(20,20))
sample = np.random.randint(0,len(dataset),64)
for i in range(16):
    img, target = dataset.__getitem__(i)
    img = img.permute(1,2,0)
    axs[i//4,i%4].imshow(img)
    axs[i//4,i%4].set_title("{} min: {:.2f} max: {:.2f}".format(dataset.classes[target],torch.min(img),torch.max(img)))
# Out:
# Files already downloaded and verified

# %%
batch_size =  512
split = (0.25, 0.25, 0.5)
training_samples = int(len(dataset) * split[0])
validation_samples = int(len(dataset) *  split[1])
test_samples = len(dataset) - training_samples - validation_samples
train_ds, valid_ds, test_ds = torch.utils.data.random_split(dataset, (training_samples, validation_samples, test_samples))

train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True)
valid_loader = DataLoader(valid_ds, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_ds, batch_size=batch_size, shuffle=False)

# %%
#Focal LOSS!!!
def extract_weights(counts, device):
    weights = np.sum(counts)/ (counts.shape[0] * counts)
    return torch.tensor(weights,dtype=torch.float).to(device)

# %%
sample = np.random.randint(0,len(dataset),5000,dtype=np.int_)
classes_subset = dataset.targets[0:20000]
hist_val,hist_x = np.histogram(classes_subset, np.arange(0,11,1))
weights  = extract_weights(hist_val,device)
print(weights)
plt.figure(figsize=(15,4))
plt.bar(hist_x[0:len(hist_x)-1],hist_val,tick_label=dataset.classes)
plt.title("Class Distribution")
# Out:
# tensor([1.0055, 1.0096, 0.9794, 0.9945, 0.9955, 1.0390, 0.9814, 0.9867, 0.9940,
#         1.0173], device='cuda:0')
# Text(0.5, 1.0, 'Class Distribution')

# %%
from prettytable import PrettyTable

def count_parameters(model):
    table = PrettyTable(["Modules", "Parameters"])
    total_params = 0
    for name, parameter in model.named_parameters():
        if not parameter.requires_grad: continue
        param = parameter.numel()
        table.add_row([name, param])
        total_params+=param
    print(table)
    print(f"Total Trainable Params: {total_params}")
    return total_params

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F


import torch.nn as nn
import torch.nn.functional as F

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, 3)
        self.conv2 = nn.Conv2d(64, 64, 3)
        self.conv3 = nn.Conv2d(64, 128, 3)
        self.pool = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(128 * 2 * 2, 128)
        self.fc2 = nn.Linear(128, 64)
        self.fc3 = nn.Linear(64, 32)
        self.fc4 = nn.Linear(32, 10)
        self.dropout1 = nn.Dropout(p=0.2, inplace=False)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.dropout1(x)
        x = self.pool(F.relu(self.conv2(x)))
        x = self.dropout1(x)
        x = self.pool(F.relu(self.conv3(x)))
        x = self.dropout1(x)
        x = x.view(-1, 128 * 2 * 2)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        x = self.fc4(x)
        return x

# %%
learning_rate = 0.001
model = Net().to(device)
criterion = nn.CrossEntropyLoss(weight=weights)
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
n_epochs=100
count_parameters(model)
# Out:
# +--------------+------------+
# |   Modules    | Parameters |
# +--------------+------------+
# | conv1.weight |    1728    |
# |  conv1.bias  |     64     |
# | conv2.weight |   36864    |
# |  conv2.bias  |     64     |
# | conv3.weight |   73728    |
# |  conv3.bias  |    128     |
# |  fc1.weight  |   65536    |
# |   fc1.bias   |    128     |
# |  fc2.weight  |    8192    |
# |   fc2.bias   |     64     |
# |  fc3.weight  |    2048    |
# |   fc3.bias   |     32     |
# |  fc4.weight  |    320     |
# |   fc4.bias   |     10     |
# +--------------+------------+
# Total Trainable Params: 188906
# 188906

# %%
plt.figure()
viz=True
avg_train_losses = []
avg_valid_losses = []
early_stopping = EarlyStopping(patience=5, verbose=True, path="net.pth")


for epoch in range(1, n_epochs + 1):
    train_losses = []
    valid_losses = []

    model.train() # prep model for training
    for input_data, classes in train_loader:
        data = input_data.to(device)
        target = classes.long().to(device)

        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, target)
        loss.backward()
        optimizer.step()
        train_losses.append(loss.item())

    model.eval()
    for input_data, classes in valid_loader:
        data = input_data.to(device)
        target = classes.long().to(device)

        output = model(data)
        loss = criterion(output, target)
        valid_losses.append(loss.item())


    train_loss = np.average(train_losses)
    valid_loss = np.average(valid_losses)

    avg_train_losses.append(train_loss)
    avg_valid_losses.append(valid_loss)

    epoch_len = len(str(n_epochs))

    print_msg = (f'[{epoch:>{epoch_len}}/{n_epochs:>{epoch_len}}] ' +
                 f'train_loss: {train_loss:.5f} ' +
                 f'valid_loss: {valid_loss:.5f}')
    print(print_msg)

    #clear_output(wait=True)

    early_stopping(valid_loss, model)

    if early_stopping.early_stop:
        print("Early stopping")
        break
    model.load_state_dict(torch.load("net.pth"))
# Out:
# [  1/100] train_loss: 2.28614 valid_loss: 2.22245
# Validation loss decreased (inf --> 2.222454).  Saving model ...
# [  2/100] train_loss: 2.13027 valid_loss: 2.07832
# Validation loss decreased (2.222454 --> 2.078320).  Saving model ...
# [  3/100] train_loss: 2.02153 valid_loss: 1.98494
# Validation loss decreased (2.078320 --> 1.984941).  Saving model ...
# [  4/100] train_loss: 1.91394 valid_loss: 1.85672
# Validation loss decreased (1.984941 --> 1.856720).  Saving model ...
# [  5/100] train_loss: 1.83332 valid_loss: 1.81231
# Validation loss decreased (1.856720 --> 1.812308).  Saving model ...
# [  6/100] train_loss: 1.78783 valid_loss: 1.75815
# Validation loss decreased (1.812308 --> 1.758151).  Saving model ...
# [  7/100] train_loss: 1.73566 valid_loss: 1.71999
# Validation loss decreased (1.758151 --> 1.719987).  Saving model ...
# [  8/100] train_loss: 1.69787 valid_loss: 1.72927
# EarlyStopping counter: 1 out of 5
# [  9/100] train_loss: 1.72225 valid_loss: 1.73753
# EarlyStopping counter: 2 out of 5
# [ 10/100] train_loss: 1.70421 valid_loss: 1.69203
# Validation loss decreased (1.719987 --> 1.692025).  Saving model ...
# [ 11/100] train_loss: 1.67890 valid_loss: 1.66864
# Validation loss decreased (1.692025 --> 1.668639).  Saving model ...
# [ 12/100] train_loss: 1.65436 valid_loss: 1.66115
# Validation loss decreased (1.668639 --> 1.661146).  Saving model ...
# [ 13/100] train_loss: 1.63433 valid_loss: 1.66078
# Validation loss decreased (1.661146 --> 1.660782).  Saving model ...
# [ 14/100] train_loss: 1.61608 valid_loss: 1.61492
# Validation loss decreased (1.660782 --> 1.614925).  Saving model ...
# [ 15/100] train_loss: 1.58251 valid_loss: 1.58060
# Validation loss decreased (1.614925 --> 1.580605).  Saving model ...
# [ 16/100] train_loss: 1.56549 valid_loss: 1.55604
# Validation loss decreased (1.580605 --> 1.556040).  Saving model ...
# [ 17/100] train_loss: 1.54972 valid_loss: 1.55164
# Validation loss decreased (1.556040 --> 1.551636).  Saving model ...
# [ 18/100] train_loss: 1.52217 valid_loss: 1.56104
# EarlyStopping counter: 1 out of 5
# [ 19/100] train_loss: 1.53018 valid_loss: 1.54762
# Validation loss decreased (1.551636 --> 1.547623).  Saving model ...
# [ 20/100] train_loss: 1.50097 valid_loss: 1.50840
# Validation loss decreased (1.547623 --> 1.508404).  Saving model ...
# [ 21/100] train_loss: 1.47313 valid_loss: 1.47385
# Validation loss decreased (1.508404 --> 1.473854).  Saving model ...
# [ 22/100] train_loss: 1.45906 valid_loss: 1.47178
# Validation loss decreased (1.473854 --> 1.471782).  Saving model ...
# [ 23/100] train_loss: 1.44324 valid_loss: 1.45011
# Validation loss decreased (1.471782 --> 1.450111).  Saving model ...
# [ 24/100] train_loss: 1.42379 valid_loss: 1.44787
# Validation loss decreased (1.450111 --> 1.447875).  Saving model ...
# [ 25/100] train_loss: 1.41774 valid_loss: 1.41715
# Validation loss decreased (1.447875 --> 1.417151).  Saving model ...
# [ 26/100] train_loss: 1.38317 valid_loss: 1.41085
# Validation loss decreased (1.417151 --> 1.410853).  Saving model ...
# [ 27/100] train_loss: 1.35720 valid_loss: 1.38598
# Validation loss decreased (1.410853 --> 1.385981).  Saving model ...
# [ 28/100] train_loss: 1.34977 valid_loss: 1.36360
# Validation loss decreased (1.385981 --> 1.363596).  Saving model ...
# [ 29/100] train_loss: 1.32463 valid_loss: 1.36043
# Validation loss decreased (1.363596 --> 1.360432).  Saving model ...
# [ 30/100] train_loss: 1.32441 valid_loss: 1.34266
# Validation loss decreased (1.360432 --> 1.342663).  Saving model ...
# [ 31/100] train_loss: 1.30122 valid_loss: 1.32851
# Validation loss decreased (1.342663 --> 1.328514).  Saving model ...
# [ 32/100] train_loss: 1.28511 valid_loss: 1.31361
# Validation loss decreased (1.328514 --> 1.313610).  Saving model ...
# [ 33/100] train_loss: 1.27841 valid_loss: 1.29370
# Validation loss decreased (1.313610 --> 1.293696).  Saving model ...
# [ 34/100] train_loss: 1.25666 valid_loss: 1.30103
# EarlyStopping counter: 1 out of 5
# [ 35/100] train_loss: 1.27982 valid_loss: 1.30576
# EarlyStopping counter: 2 out of 5
# [ 36/100] train_loss: 1.25531 valid_loss: 1.29342
# Validation loss decreased (1.293696 --> 1.293423).  Saving model ...
# [ 37/100] train_loss: 1.24024 valid_loss: 1.26903
# Validation loss decreased (1.293423 --> 1.269034).  Saving model ...
# [ 38/100] train_loss: 1.23704 valid_loss: 1.25868
# Validation loss decreased (1.269034 --> 1.258685).  Saving model ...
# [ 39/100] train_loss: 1.21121 valid_loss: 1.25480
# Validation loss decreased (1.258685 --> 1.254801).  Saving model ...
# [ 40/100] train_loss: 1.19719 valid_loss: 1.24590
# Validation loss decreased (1.254801 --> 1.245898).  Saving model ...
# [ 41/100] train_loss: 1.20889 valid_loss: 1.23882
# Validation loss decreased (1.245898 --> 1.238823).  Saving model ...
# [ 42/100] train_loss: 1.18676 valid_loss: 1.22214
# Validation loss decreased (1.238823 --> 1.222139).  Saving model ...
# [ 43/100] train_loss: 1.15637 valid_loss: 1.20337
# Validation loss decreased (1.222139 --> 1.203371).  Saving model ...
# [ 44/100] train_loss: 1.15364 valid_loss: 1.21297
# EarlyStopping counter: 1 out of 5
# [ 45/100] train_loss: 1.15717 valid_loss: 1.21645
# EarlyStopping counter: 2 out of 5
# [ 46/100] train_loss: 1.15096 valid_loss: 1.23264
# EarlyStopping counter: 3 out of 5
# [ 47/100] train_loss: 1.15652 valid_loss: 1.22142
# EarlyStopping counter: 4 out of 5
# [ 48/100] train_loss: 1.16435 valid_loss: 1.21822
# EarlyStopping counter: 5 out of 5
# Early stopping

# %%
if viz:
    xx = np.arange(0,len(avg_valid_losses),1)
    y_valid = np.array(avg_valid_losses)
    y_train =  np.array(avg_train_losses)
    plt.plot(xx, y_valid)
    plt.plot(xx, y_train,color='red')
    plt.legend(("Validation Loss","Training Loss"),labelcolor='black')
    plt.xlabel("Epochs")
    plt.ylabel("loss")
    plt.title("Loss of validation and training set")
    plt.show()

# %%
y_gts = np.array([])
y_preds = np.array([])
dataset.transform = min_transform
test_loss=[]
for input_data, classes in test_loader:
    x = input_data.to(device)
    y = classes.long().to(device)
    y_pred = model(x)
    loss = criterion(y_pred, y)
    _, pred = torch.max(y_pred, 1)

    y_gts = np.hstack((y_gts, y.cpu().numpy()))
    y_preds = np.hstack((y_preds, pred.cpu().numpy()))

print("Accuracy of: {}".format(np.sum(y_gts==y_preds)/y_preds.shape[0]))
# Out:
# Accuracy of: 0.56872

# %%
import seaborn as sn
import numpy as np
from sklearn.metrics import confusion_matrix,plot_confusion_matrix

from sklearn import metrics

cm = confusion_matrix(y_gts,y_preds) #TP first
sn.set(font_scale=1.5) # for label size

plt.figure(figsize=(25,25))
group_counts = ["{0:0.0f}".format(value) for value in
                    cm.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in
                         cm.flatten()/np.sum(cm)]
labels = [f"{v1}\n{v2}\n" for v1, v2 in
              zip(group_counts,group_percentages)]
labels = np.asarray(labels).reshape(10,10)

ax = sn.heatmap(cm,
                annot=labels,
                fmt="",
                cmap="Blues",xticklabels=dataset.classes, yticklabels=dataset.classes,)

# 1. Premyslite si a implemntujte modifikaciu ktora konzistentne zvysi accuracy.
# 2. Skuste sa dostat nad accuracy >70%.
