# %% [markdown]
# # 6. Transfer learning

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F


import torch.nn as nn
import torch.nn.functional as F

import numpy as np
import matplotlib.pyplot as plt
import torch
import torchvision
from torch.utils.data import DataLoader
from IPython.display import clear_output
from early_stopping.pytorchtools import EarlyStopping

# %matplotlib inline
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')


plt.rcParams['text.color'] = 'w'
plt.rcParams['xtick.color'] = 'w'
plt.rcParams['ytick.color'] = 'w'
plt.rcParams['axes.labelcolor'] = 'w'
font = {'family' : 'DejaVu Sans',
        'weight' : 'normal',
        'size'   : 14}
plt.rc('font', **font)

# %%
min_transform = torchvision.transforms.Compose([
                                    torchvision.transforms.Resize((128,128)),
                                    torchvision.transforms.ToTensor()
                                    ])
dataset = torchvision.datasets.CIFAR10("/media/miro/4tb_cached/",
                                       transform=min_transform,
                                       download=True)

fig, axs = plt.subplots(4, 4,figsize=(20,20))
sample = np.random.randint(0,len(dataset),64)
for i in range(16):
    img, target = dataset.__getitem__(sample[i])
    img = img.permute(1,2,0)
    axs[i//4,i%4].imshow(img)
    axs[i//4,i%4].set_title("{} min: {:.2f} max: {:.2f}".format(dataset.classes[target],torch.min(img),torch.max(img)))
# Out:
# Files already downloaded and verified

# %%
batch_size =  8
split = (0.4, 0.3, 0.3)
training_samples = int(len(dataset) * split[0])
validation_samples = int(len(dataset) *  split[1])
test_samples = len(dataset) - training_samples - validation_samples
train_ds, valid_ds, test_ds = torch.utils.data.random_split(dataset, (training_samples, validation_samples, test_samples))

train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True)
valid_loader = DataLoader(valid_ds, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_ds, batch_size=batch_size, shuffle=False)

# %%
def train(model, n_epochs,train_loader,valid_loader,criterion,optimizer,scheduler=None,early_stop_count=0):
    avg_train_losses = []
    avg_valid_losses = []
    avg_valid_acc = []
    batch_train_losses= []

    early_stopping = EarlyStopping(patience=early_stop_count, verbose=True, path="net.pth")

    for epoch in range(1, n_epochs + 1):
        train_losses = []
        valid_losses = []
        valid_accs = []

        model.train() # prep model for training
        for input_data, classes in train_loader:
            data = input_data.to(device)
            target = classes.long().to(device)

            optimizer.zero_grad()
            output = model(data)
            loss = criterion(output, target)
            loss.backward()
            optimizer.step()
            train_losses.append(loss.item())

        model.eval()
        for input_data, classes in valid_loader:
            data = input_data.to(device)
            target = classes.long().to(device)

            output = model(data)
            loss = criterion(output, target)
            valid_losses.append(loss.item())

            _, pred = torch.max(output, 1)

            valid_accs.append(np.sum(target.cpu().numpy() == pred.cpu().numpy()) / pred.shape[0])



        train_loss = np.average(train_losses)
        valid_loss = np.average(valid_losses)
        valid_acc = np.average(valid_accs)

        if scheduler:
            scheduler.step()

        avg_train_losses.append(train_loss)
        avg_valid_losses.append(valid_loss)
        avg_valid_acc.append(valid_acc)
        batch_train_losses.extend(train_losses)

        epoch_len = len(str(n_epochs))

        print_msg = (f'[{epoch:>{epoch_len}}/{n_epochs:>{epoch_len}}] ' +
                     f'train_loss: {train_loss:.5f} ' +
                     f'valid_loss: {valid_loss:.5f} '
                     f'valid_acc: {valid_acc*100:2.2f} %')
        if scheduler:
            print_msg = print_msg + " lr: {:.5f}".format(scheduler.get_last_lr()[0])
        print(print_msg)

        if early_stop_count:
            early_stopping(valid_loss, model)

            if early_stopping.early_stop:
                print("Early stopping")
                break
    if early_stop_count:
        model.load_state_dict(torch.load("net.pth"))

    return avg_valid_losses, avg_train_losses, model, batch_train_losses

# %%
def print_accuracy(model, criterion, test_loader):
    y_gts = np.array([])
    y_preds = np.array([])
    for input_data, classes in test_loader:
        x = input_data.to(device)
        y = classes.long().to(device)
        output = model(x)
        _, pred = torch.max(output, 1)

        y_gts = np.hstack((y_gts, y.cpu().numpy()))
        y_preds = np.hstack((y_preds, pred.cpu().numpy()))

    print("Accuracy the NN is : {:2.2f} %".format(np.sum(y_gts==y_preds)/y_preds.shape[0]*100))


def visualize_batch_loss(batch_train_losses):
    plt.figure(figsize=(15,3))
    xx = np.arange(0,len(batch_train_losses),1)
    y_train =  np.array(batch_train_losses)
    plt.plot(xx, y_train)
    plt.legend(["Training Loss"],labelcolor='black')
    plt.xlabel("Batches")
    plt.ylabel("Loss")
    plt.title("Loss of validation and training set")
    plt.show()

def visualize_loss(avg_valid_losses,avg_train_losses):
    plt.figure()
    xx = np.arange(0,len(avg_valid_losses),1)
    y_valid = np.array(avg_valid_losses)
    y_train =  np.array(avg_train_losses)
    plt.plot(xx, y_valid)
    plt.plot(xx, y_train,color='red')
    plt.legend(("Validation Loss","Training Loss"),labelcolor='black')
    plt.xlabel("Epochs")
    plt.ylabel("loss")
    plt.title("Loss of validation and training set")
    plt.show()

# %% [markdown]
# ## ResNet 18

# %%
from torchsummary import summary

model = torchvision.models.resnet18(pretrained=True)
model = model.to(device)

summary(model, input_size=(3, 224, 224),batch_size=32)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [32, 64, 112, 112]           9,408
#        BatchNorm2d-2         [32, 64, 112, 112]             128
#               ReLU-3         [32, 64, 112, 112]               0
#          MaxPool2d-4           [32, 64, 56, 56]               0
#             Conv2d-5           [32, 64, 56, 56]          36,864
#        BatchNorm2d-6           [32, 64, 56, 56]             128
#               ReLU-7           [32, 64, 56, 56]               0
#             Conv2d-8           [32, 64, 56, 56]          36,864
#        BatchNorm2d-9           [32, 64, 56, 56]             128
#              ReLU-10           [32, 64, 56, 56]               0
#        BasicBlock-11           [32, 64, 56, 56]               0
#            Conv2d-12           [32, 64, 56, 56]          36,864
#       BatchNorm2d-13           [32, 64, 56, 56]             128
#              ReLU-14           [32, 64, 56, 56]               0
#            Conv2d-15           [32, 64, 56, 56]          36,864
#       BatchNorm2d-16           [32, 64, 56, 56]             128
#              ReLU-17           [32, 64, 56, 56]               0
#        BasicBlock-18           [32, 64, 56, 56]               0
#            Conv2d-19          [32, 128, 28, 28]          73,728
#       BatchNorm2d-20          [32, 128, 28, 28]             256
#              ReLU-21          [32, 128, 28, 28]               0
#            Conv2d-22          [32, 128, 28, 28]         147,456
#       BatchNorm2d-23          [32, 128, 28, 28]             256
#            Conv2d-24          [32, 128, 28, 28]           8,192
#       BatchNorm2d-25          [32, 128, 28, 28]             256
#              ReLU-26          [32, 128, 28, 28]               0
#        BasicBlock-27          [32, 128, 28, 28]               0
#            Conv2d-28          [32, 128, 28, 28]         147,456
#       BatchNorm2d-29          [32, 128, 28, 28]             256
#              ReLU-30          [32, 128, 28, 28]               0
#            Conv2d-31          [32, 128, 28, 28]         147,456
#       BatchNorm2d-32          [32, 128, 28, 28]             256
#              ReLU-33          [32, 128, 28, 28]               0
#        BasicBlock-34          [32, 128, 28, 28]               0
#            Conv2d-35          [32, 256, 14, 14]         294,912
#       BatchNorm2d-36          [32, 256, 14, 14]             512
#              ReLU-37          [32, 256, 14, 14]               0
#            Conv2d-38          [32, 256, 14, 14]         589,824
#       BatchNorm2d-39          [32, 256, 14, 14]             512
#            Conv2d-40          [32, 256, 14, 14]          32,768
#       BatchNorm2d-41          [32, 256, 14, 14]             512
#              ReLU-42          [32, 256, 14, 14]               0
#        BasicBlock-43          [32, 256, 14, 14]               0
#            Conv2d-44          [32, 256, 14, 14]         589,824
#       BatchNorm2d-45          [32, 256, 14, 14]             512
#              ReLU-46          [32, 256, 14, 14]               0
#            Conv2d-47          [32, 256, 14, 14]         589,824
#       BatchNorm2d-48          [32, 256, 14, 14]             512
#              ReLU-49          [32, 256, 14, 14]               0
#        BasicBlock-50          [32, 256, 14, 14]               0
#            Conv2d-51            [32, 512, 7, 7]       1,179,648
#       BatchNorm2d-52            [32, 512, 7, 7]           1,024
#              ReLU-53            [32, 512, 7, 7]               0
#            Conv2d-54            [32, 512, 7, 7]       2,359,296
#       BatchNorm2d-55            [32, 512, 7, 7]           1,024
#            Conv2d-56            [32, 512, 7, 7]         131,072
#       BatchNorm2d-57            [32, 512, 7, 7]           1,024
#              ReLU-58            [32, 512, 7, 7]               0
#        BasicBlock-59            [32, 512, 7, 7]               0
#            Conv2d-60            [32, 512, 7, 7]       2,359,296
#       BatchNorm2d-61            [32, 512, 7, 7]           1,024
#              ReLU-62            [32, 512, 7, 7]               0
#            Conv2d-63            [32, 512, 7, 7]       2,359,296
#       BatchNorm2d-64            [32, 512, 7, 7]           1,024
#              ReLU-65            [32, 512, 7, 7]               0
#        BasicBlock-66            [32, 512, 7, 7]               0
# AdaptiveAvgPool2d-67            [32, 512, 1, 1]               0
#            Linear-68                 [32, 1000]         513,000
# ================================================================
# Total params: 11,689,512
# Trainable params: 11,689,512
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 18.38
# Forward/backward pass size (MB): 2009.37
# Params size (MB): 44.59
# Estimated Total Size (MB): 2072.34
# ----------------------------------------------------------------

# %% [markdown]
# ### 1. ConvNet as fixed feature extractor:
# * load ResNet
# * input size should 224 by 224, but avg pool helps
# * http://www.image-net.org/index
# * https://paperswithcode.com/sota/image-classification-on-imagenet

# %%
for param in model.parameters():
    param.requires_grad = False

num_ftrs = model.fc.in_features

model.fc = nn.Sequential(
    nn.Linear(num_ftrs, 10)
)

model.fc.requires_grad = True # not neccesary

model = model.to(device)
summary(model, input_size=(3, 128, 128),batch_size=32)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [32, 64, 64, 64]           9,408
#        BatchNorm2d-2           [32, 64, 64, 64]             128
#               ReLU-3           [32, 64, 64, 64]               0
#          MaxPool2d-4           [32, 64, 32, 32]               0
#             Conv2d-5           [32, 64, 32, 32]          36,864
#        BatchNorm2d-6           [32, 64, 32, 32]             128
#               ReLU-7           [32, 64, 32, 32]               0
#             Conv2d-8           [32, 64, 32, 32]          36,864
#        BatchNorm2d-9           [32, 64, 32, 32]             128
#              ReLU-10           [32, 64, 32, 32]               0
#        BasicBlock-11           [32, 64, 32, 32]               0
#            Conv2d-12           [32, 64, 32, 32]          36,864
#       BatchNorm2d-13           [32, 64, 32, 32]             128
#              ReLU-14           [32, 64, 32, 32]               0
#            Conv2d-15           [32, 64, 32, 32]          36,864
#       BatchNorm2d-16           [32, 64, 32, 32]             128
#              ReLU-17           [32, 64, 32, 32]               0
#        BasicBlock-18           [32, 64, 32, 32]               0
#            Conv2d-19          [32, 128, 16, 16]          73,728
#       BatchNorm2d-20          [32, 128, 16, 16]             256
#              ReLU-21          [32, 128, 16, 16]               0
#            Conv2d-22          [32, 128, 16, 16]         147,456
#       BatchNorm2d-23          [32, 128, 16, 16]             256
#            Conv2d-24          [32, 128, 16, 16]           8,192
#       BatchNorm2d-25          [32, 128, 16, 16]             256
#              ReLU-26          [32, 128, 16, 16]               0
#        BasicBlock-27          [32, 128, 16, 16]               0
#            Conv2d-28          [32, 128, 16, 16]         147,456
#       BatchNorm2d-29          [32, 128, 16, 16]             256
#              ReLU-30          [32, 128, 16, 16]               0
#            Conv2d-31          [32, 128, 16, 16]         147,456
#       BatchNorm2d-32          [32, 128, 16, 16]             256
#              ReLU-33          [32, 128, 16, 16]               0
#        BasicBlock-34          [32, 128, 16, 16]               0
#            Conv2d-35            [32, 256, 8, 8]         294,912
#       BatchNorm2d-36            [32, 256, 8, 8]             512
#              ReLU-37            [32, 256, 8, 8]               0
#            Conv2d-38            [32, 256, 8, 8]         589,824
#       BatchNorm2d-39            [32, 256, 8, 8]             512
#            Conv2d-40            [32, 256, 8, 8]          32,768
#       BatchNorm2d-41            [32, 256, 8, 8]             512
#              ReLU-42            [32, 256, 8, 8]               0
#        BasicBlock-43            [32, 256, 8, 8]               0
#            Conv2d-44            [32, 256, 8, 8]         589,824
#       BatchNorm2d-45            [32, 256, 8, 8]             512
#              ReLU-46            [32, 256, 8, 8]               0
#            Conv2d-47            [32, 256, 8, 8]         589,824
#       BatchNorm2d-48            [32, 256, 8, 8]             512
#              ReLU-49            [32, 256, 8, 8]               0
#        BasicBlock-50            [32, 256, 8, 8]               0
#            Conv2d-51            [32, 512, 4, 4]       1,179,648
#       BatchNorm2d-52            [32, 512, 4, 4]           1,024
#              ReLU-53            [32, 512, 4, 4]               0
#            Conv2d-54            [32, 512, 4, 4]       2,359,296
#       BatchNorm2d-55            [32, 512, 4, 4]           1,024
#            Conv2d-56            [32, 512, 4, 4]         131,072
#       BatchNorm2d-57            [32, 512, 4, 4]           1,024
#              ReLU-58            [32, 512, 4, 4]               0
#        BasicBlock-59            [32, 512, 4, 4]               0
#            Conv2d-60            [32, 512, 4, 4]       2,359,296
#       BatchNorm2d-61            [32, 512, 4, 4]           1,024
#              ReLU-62            [32, 512, 4, 4]               0
#            Conv2d-63            [32, 512, 4, 4]       2,359,296
#       BatchNorm2d-64            [32, 512, 4, 4]           1,024
#              ReLU-65            [32, 512, 4, 4]               0
#        BasicBlock-66            [32, 512, 4, 4]               0
# AdaptiveAvgPool2d-67            [32, 512, 1, 1]               0
#            Linear-68                   [32, 10]           5,130
# ================================================================
# Total params: 11,181,642
# Trainable params: 5,130
# Non-trainable params: 11,176,512
# ----------------------------------------------------------------
# Input size (MB): 6.00
# Forward/backward pass size (MB): 656.13
# Params size (MB): 42.65
# Estimated Total Size (MB): 704.78
# ----------------------------------------------------------------

# %%
optimizer = torch.optim.Adam(model.fc.parameters(), lr=0.001)

criterion_CE = torch.nn.CrossEntropyLoss()
avg_valid_losses, avg_train_losses, model,batch_train_losses = train(model,5,train_loader,valid_loader,
                                                                     criterion=criterion_CE,
                                                                     optimizer=optimizer)
visualize_loss(avg_valid_losses,avg_train_losses)
visualize_batch_loss(batch_train_losses=batch_train_losses)

print_accuracy(model,
               criterion=criterion_CE,
               test_loader=test_loader)
# Out:
# [1/5] train_loss: 0.93981 valid_loss: 0.73589 valid_acc: 74.87 %
# [2/5] train_loss: 0.71778 valid_loss: 0.66831 valid_acc: 77.08 %
# [3/5] train_loss: 0.68834 valid_loss: 0.67451 valid_acc: 76.96 %
# [4/5] train_loss: 0.66837 valid_loss: 0.64198 valid_acc: 77.75 %
# [5/5] train_loss: 0.65264 valid_loss: 0.66413 valid_acc: 77.35 %
# Accuracy the NN is : 77.38 %

# %% [markdown]
# ### 2. Fine-tuning the ConvNet.
# #### A. Fine tuning full CNN

# %%
from efficientnet_pytorch.model import EfficientNet

model = EfficientNet.from_pretrained('efficientnet-b0')

model = model.to(device)
summary(model, input_size=(3, 128, 128),batch_size=8)
# Out:
# Loaded pretrained weights for efficientnet-b0
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#          ZeroPad2d-1           [8, 3, 130, 130]               0
# Conv2dStaticSamePadding-2            [8, 32, 64, 64]             864
#        BatchNorm2d-3            [8, 32, 64, 64]              64
# MemoryEfficientSwish-4            [8, 32, 64, 64]               0
#          ZeroPad2d-5            [8, 32, 66, 66]               0
# Conv2dStaticSamePadding-6            [8, 32, 64, 64]             288
#        BatchNorm2d-7            [8, 32, 64, 64]              64
# MemoryEfficientSwish-8            [8, 32, 64, 64]               0
#           Identity-9              [8, 32, 1, 1]               0
# Conv2dStaticSamePadding-10               [8, 8, 1, 1]             264
# MemoryEfficientSwish-11               [8, 8, 1, 1]               0
#          Identity-12               [8, 8, 1, 1]               0
# Conv2dStaticSamePadding-13              [8, 32, 1, 1]             288
#          Identity-14            [8, 32, 64, 64]               0
# Conv2dStaticSamePadding-15            [8, 16, 64, 64]             512
#       BatchNorm2d-16            [8, 16, 64, 64]              32
#       MBConvBlock-17            [8, 16, 64, 64]               0
#          Identity-18            [8, 16, 64, 64]               0
# Conv2dStaticSamePadding-19            [8, 96, 64, 64]           1,536
#       BatchNorm2d-20            [8, 96, 64, 64]             192
# MemoryEfficientSwish-21            [8, 96, 64, 64]               0
#         ZeroPad2d-22            [8, 96, 66, 66]               0
# Conv2dStaticSamePadding-23            [8, 96, 32, 32]             864
#       BatchNorm2d-24            [8, 96, 32, 32]             192
# MemoryEfficientSwish-25            [8, 96, 32, 32]               0
#          Identity-26              [8, 96, 1, 1]               0
# Conv2dStaticSamePadding-27               [8, 4, 1, 1]             388
# MemoryEfficientSwish-28               [8, 4, 1, 1]               0
#          Identity-29               [8, 4, 1, 1]               0
# Conv2dStaticSamePadding-30              [8, 96, 1, 1]             480
#          Identity-31            [8, 96, 32, 32]               0
# Conv2dStaticSamePadding-32            [8, 24, 32, 32]           2,304
#       BatchNorm2d-33            [8, 24, 32, 32]              48
#       MBConvBlock-34            [8, 24, 32, 32]               0
#          Identity-35            [8, 24, 32, 32]               0
# Conv2dStaticSamePadding-36           [8, 144, 32, 32]           3,456
#       BatchNorm2d-37           [8, 144, 32, 32]             288
# MemoryEfficientSwish-38           [8, 144, 32, 32]               0
# Conv2dStaticSamePadding-202             [8, 192, 4, 4]         129,024
#      BatchNorm2d-203             [8, 192, 4, 4]             384
#      MBConvBlock-204             [8, 192, 4, 4]               0
#         Identity-205             [8, 192, 4, 4]               0
# Conv2dStaticSamePadding-206            [8, 1152, 4, 4]         221,184
#      BatchNorm2d-207            [8, 1152, 4, 4]           2,304
# MemoryEfficientSwish-208            [8, 1152, 4, 4]               0
#        ZeroPad2d-209            [8, 1152, 8, 8]               0
# Conv2dStaticSamePadding-210            [8, 1152, 4, 4]          28,800
#      BatchNorm2d-211            [8, 1152, 4, 4]           2,304
# MemoryEfficientSwish-212            [8, 1152, 4, 4]               0
#         Identity-213            [8, 1152, 1, 1]               0
# Conv2dStaticSamePadding-214              [8, 48, 1, 1]          55,344
# MemoryEfficientSwish-215              [8, 48, 1, 1]               0
#         Identity-216              [8, 48, 1, 1]               0
# Conv2dStaticSamePadding-217            [8, 1152, 1, 1]          56,448
#         Identity-218            [8, 1152, 4, 4]               0
# Conv2dStaticSamePadding-219             [8, 192, 4, 4]         221,184
#      BatchNorm2d-220             [8, 192, 4, 4]             384
#      MBConvBlock-221             [8, 192, 4, 4]               0
#         Identity-222             [8, 192, 4, 4]               0
# Conv2dStaticSamePadding-223            [8, 1152, 4, 4]         221,184
#      BatchNorm2d-224            [8, 1152, 4, 4]           2,304
# MemoryEfficientSwish-225            [8, 1152, 4, 4]               0
#        ZeroPad2d-226            [8, 1152, 8, 8]               0
# Conv2dStaticSamePadding-227            [8, 1152, 4, 4]          28,800
#      BatchNorm2d-228            [8, 1152, 4, 4]           2,304
# MemoryEfficientSwish-229            [8, 1152, 4, 4]               0
#         Identity-230            [8, 1152, 1, 1]               0
# Conv2dStaticSamePadding-231              [8, 48, 1, 1]          55,344
# MemoryEfficientSwish-232              [8, 48, 1, 1]               0
#         Identity-233              [8, 48, 1, 1]               0
# Conv2dStaticSamePadding-234            [8, 1152, 1, 1]          56,448
#         Identity-235            [8, 1152, 4, 4]               0
# Conv2dStaticSamePadding-236             [8, 192, 4, 4]         221,184
#      BatchNorm2d-237             [8, 192, 4, 4]             384
#      MBConvBlock-238             [8, 192, 4, 4]               0
#         Identity-239             [8, 192, 4, 4]               0
# Conv2dStaticSamePadding-240            [8, 1152, 4, 4]         221,184
#      BatchNorm2d-241            [8, 1152, 4, 4]           2,304
# MemoryEfficientSwish-242            [8, 1152, 4, 4]               0
#        ZeroPad2d-243            [8, 1152, 8, 8]               0
# Conv2dStaticSamePadding-244            [8, 1152, 4, 4]          28,800
#      BatchNorm2d-245            [8, 1152, 4, 4]           2,304
# MemoryEfficientSwish-246            [8, 1152, 4, 4]               0
#         Identity-247            [8, 1152, 1, 1]               0
# Conv2dStaticSamePadding-248              [8, 48, 1, 1]          55,344
# MemoryEfficientSwish-249              [8, 48, 1, 1]               0
#         Identity-250              [8, 48, 1, 1]               0
# Conv2dStaticSamePadding-251            [8, 1152, 1, 1]          56,448
#         Identity-252            [8, 1152, 4, 4]               0
# Conv2dStaticSamePadding-253             [8, 192, 4, 4]         221,184
#      BatchNorm2d-254             [8, 192, 4, 4]             384
#      MBConvBlock-255             [8, 192, 4, 4]               0
#         Identity-256             [8, 192, 4, 4]               0
# Conv2dStaticSamePadding-257            [8, 1152, 4, 4]         221,184
#      BatchNorm2d-258            [8, 1152, 4, 4]           2,304
# MemoryEfficientSwish-259            [8, 1152, 4, 4]               0
#        ZeroPad2d-260            [8, 1152, 6, 6]               0
# Conv2dStaticSamePadding-261            [8, 1152, 4, 4]          10,368
#      BatchNorm2d-262            [8, 1152, 4, 4]           2,304
# MemoryEfficientSwish-263            [8, 1152, 4, 4]               0
#         Identity-264            [8, 1152, 1, 1]               0
# Conv2dStaticSamePadding-265              [8, 48, 1, 1]          55,344
# MemoryEfficientSwish-266              [8, 48, 1, 1]               0
#         Identity-267              [8, 48, 1, 1]               0
# Conv2dStaticSamePadding-268            [8, 1152, 1, 1]          56,448
#         Identity-269            [8, 1152, 4, 4]               0
# Conv2dStaticSamePadding-270             [8, 320, 4, 4]         368,640
#      BatchNorm2d-271             [8, 320, 4, 4]             640
#      MBConvBlock-272             [8, 320, 4, 4]               0
#         Identity-273             [8, 320, 4, 4]               0
# Conv2dStaticSamePadding-274            [8, 1280, 4, 4]         409,600
#      BatchNorm2d-275            [8, 1280, 4, 4]           2,560
# MemoryEfficientSwish-276            [8, 1280, 4, 4]               0
# AdaptiveAvgPool2d-277            [8, 1280, 1, 1]               0
#          Dropout-278                  [8, 1280]               0
#           Linear-279                  [8, 1000]       1,281,000
# ================================================================
# Total params: 5,288,548
# Trainable params: 5,288,548
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 1.50
# Forward/backward pass size (MB): 574.87
# Params size (MB): 20.17
# Estimated Total Size (MB): 596.54
# ----------------------------------------------------------------

# %%
num_ftrs = model._fc.out_features
model.classifier = nn.Sequential(
            nn.Dropout(0.2),
            nn.Linear(num_ftrs, 10))


optimizer =torch.optim.Adam(model.parameters(), lr=0.0001)
model = model.to(device)

# %%
criterion_CE= torch.nn.CrossEntropyLoss()
avg_valid_losses, avg_train_losses, model,batch_train_losses = train(model,5,train_loader,valid_loader,
                                                                     criterion=criterion_CE,
                                                                     optimizer=optimizer)
visualize_loss(avg_valid_losses,avg_train_losses)
visualize_batch_loss(batch_train_losses=batch_train_losses)

print_accuracy(model,
               criterion=criterion_CE,
               test_loader=test_loader)
# Out:
# [1/5] train_loss: 1.04243 valid_loss: 0.32969 valid_acc: 89.53 %
# [2/5] train_loss: 0.42398 valid_loss: 0.27894 valid_acc: 91.02 %
# [3/5] train_loss: 0.29591 valid_loss: 0.23193 valid_acc: 92.30 %
# [4/5] train_loss: 0.20226 valid_loss: 0.21251 valid_acc: 93.07 %
# [5/5] train_loss: 0.15007 valid_loss: 0.23977 valid_acc: 92.61 %
# Accuracy the NN is : 92.39 %

# %% [markdown]
# ### 3. Pretrained models.
# * https://modelzoo.co/
# * https://github.com/

# %% [markdown]
# Uloha1.: Ako zmenit trenovaciu slucku aby som dokazal na 4Gb grafickej karte trenovat EfficientNet-B9 so vstupom 64x3x224x224. Zmenu implementujte. (5b)
#
# Uloha2.: Naucte siet podla vlastneho vyberu s predtrenovanymi konvolucnymi maskami na CIFAR 10 bud ako fixny extraktor alebo vyladenie celej konvolucnej siete.
